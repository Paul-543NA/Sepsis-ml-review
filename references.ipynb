# %% [markdown]
# # Inspect references

# %%
import os
import pandas as pd
import matplotlib. pyplot as plt

# %% [markdown]
# ## Merge all references into single DataFrame

# %%
df = {
    'irrelevant': pd.read_csv(os.path.join('data', 'references', 'review_176995_irrelevant_csv_20220512005557.csv')),
    'excluded': pd.read_csv(os.path.join('data', 'references', 'review_176995_excluded_csv_20220512005107.csv')),
    'included': pd.read_csv(os.path.join('data', 'references', 'review_176995_included_csv_20220512024607.csv'))
}

# %%
for decision in df.keys():
    df[decision]['decision'] = decision

# %%
df['all'] = pd.concat(df.values()).reset_index(drop=True)

# %% [markdown]
# Replace NaN title with empty string to allow easy searching:

# %%
df['all'].loc[df['all'].Title.isnull(), 'Title'] = ''

# %% [markdown]
# ## Search for Eliza's papers

# %%
df['all'].loc[df['all'].Title.str.contains('early sepsis detection', case=False)]
# Out:
#                                                   Title  \
# 1971  Post Market Observational Study of ESId (MDW H...
# 2180  Randomized Controlled Trial of a Machine Learn...
# 2381  Post Market Observational Study of ESId (MDW H...
# 3988  An Improved Multi-Output Gaussian Process RNN ...
#
#                                                 Authors  \
# 1971                             Amin A Mohammad, Ph D.
# 2180                                  Ritankar Das, MSc
# 2381                              Tiffany Osborn, M. D.
# 3988  Futoma, Joseph; Hariharan, Sanjay; Sendak, Mar...
#
#                                                Abstract  Published Year  \
# 1971  The purpose of this study is to demonstrate th...          2020.0
# 2180  The focus of this study will be to conduct a p...          2019.0
# 2381  The purpose of this study is to demonstrate th...          2020.0
# 3988  Sepsis is a poorly understood and potentially ...          2017.0
#
# ...

# %%
df['all'].loc[df['all'].Title.str.contains('multicentre validation', case=False)]
# Out:
#                                                   Title  \
# 4520  Multicentre validation of a sepsis prediction ...
#
#                                                 Authors  \
# 4520  Mao, Qingqing; Jay, Melissa; Hoffman, Jana L.;...
#
#                                                Abstract  Published Year  \
# 4520  Objectives We validate a machine learning-base...          2018.0
#
#      Published Month   Journal Volume Issue    Pages  Accession Number  \
# 4520             NaN  BMJ Open      8   1.0  e017833               NaN
#
#                                                 DOI  Ref Covidence #  \
# 4520  http://dx.doi.org/10.1136/bmjopen-2017-017833  NaN       #2846
#
#          Study                                              Notes  Tags  \
# 4520  Mao 2018  Myura Nagendran (2022-01-18 02:06:05)(Select):...   NaN
#
#       decision
# 4520  included

# %%
df['all'].loc[df['all'].Title.str.contains('severe sepsis prediction algorithm', case=False)]
# Out:
# Empty DataFrame
# Columns: [Title, Authors, Abstract, Published Year, Published Month, Journal, Volume, Issue, Pages, Accession Number, DOI, Ref, Covidence #, Study, Notes, Tags, decision]
# Index: []

# %%
df['all'].loc[df['all'].Title.str.contains('prediction of sepsis in the', case=False)]
# Out:
#                                                   Title  \
# 350   Early Prediction of Sepsis in the ICU Using Ma...
# 801   Early Prediction of Sepsis in the ICU using Ma...
# 1229  An Interpretable Deep Learning Model for Early...
#
#                                                 Authors  \
# 350   Moor, Michael; Rieck, Bastian; Horn, Max; Jutz...
# 801   Moor, M.; Rieck, B.; Horn, M.; Jutzeler, C.; B...
# 1229  Zhang, D.; Yin, C.; Hunold, K. M.; Jiang, X.; ...
#
#                                                Abstract  Published Year  \
# 350   Background: Sepsis is among the leading causes...          2021.0
# 801   AO_SCPLOWBSTRACTC_SCPLOWO_ST_ABSBackgroundC_ST...          2020.0
# 1229  BackgroundSepsis, a life-threatening illness c...          2020.0
#
#      Published Month                Journal Volume Issue   Pages  \
# 350              NaN  Frontiers in Medicine      8   NaN  607952
# 801              NaN                    NaN    NaN   NaN     NaN
# ...

# %%
df['all'].loc[df['all'].Title.str.contains('prediction of fluid responsiveness', case=False)]
# Out:
#                                                   Title  \
# 968   Prediction of fluid responsiveness in septic s...
# 4496  Pulse pressure variation and prediction of flu...
#
#                                                 Authors  \
# 968                Khwannimit, B.; Bhurayanontachai, R.
# 4496  de Oliveira-Costa, C. D. A.; Friedman, G.; Vie...
#
#                                                Abstract  Published Year  \
# 968   Objectives The aim of this study was to assess...          2012.0
# 4496  Objective: To determine the utility of pulse p...          2012.0
#
#      Published Month                              Journal Volume Issue  \
# 968              NaN  European Journal of Anaesthesiology     29     2
# 4496             NaN                              Clinics     67   7.0
#
#         Pages  Accession Number                           DOI  Ref  \
# 968     64-69               NaN  10.1097/EJA.0b013e32834b7d82  NaN
# ...

# %%
df['all'].loc[df['all'].Title.str.contains('fluid responsiveness prediction', case=False)]
# Out:
#                                                   Title  \
# 4382  Machine learning methods to improve bedside fl...
#
#                                                 Authors  \
# 4382  Bataille, Benoit; de Selle, Jade; Moussot, Pie...
#
#                                                Abstract  Published Year  \
# 4382  BACKGROUND: Passive leg raising (PLR) predicts...          2021.0
#
#      Published Month                         Journal Volume Issue    Pages  \
# 4382             NaN  British Journal of Anaesthesia    126     4  826-834
#
#       Accession Number                                           DOI  Ref  \
# 4382               NaN  https://dx.doi.org/10.1016/j.bja.2020.11.039  NaN
#
#      Covidence #          Study  \
# 4382       #4702  Bataille 2021
#
#                                                   Notes  Tags  decision
# 4382  Exclusion reason: Non-routinely-collected data...   NaN  excluded
