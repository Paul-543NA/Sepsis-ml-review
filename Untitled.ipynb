# %% [markdown]
# # Large scale plots

# %%
import os
import pandas as pd
import matplotlib. pyplot as plt

plt.style.use("ggplot")

# %%
papers_df = pd.read_csv(os.path.join("data", "review_176995_20220502220126.csv"))
papers_df
# Out:
#     Covidence #        Study ID  \
# 0          6165         Yu 2019
# 1          6139         Ho 2014
# 2          6130  Watkinson 2021
# 3          6117      Jeter 2021
# 4          6067        Zhu 2021
# ..          ...             ...
# 70           27      Mitra 2018
# 71           26         Li 2018
# 72           19      Raghu 2017
# 73           18      Raghu 2017
# 74            9   Robinson 2016
#
#                                                 Title Reviewer Name  \
# 0   Deep Inverse Reinforcement Learning for Sepsis...     Consensus
# 1   Septic Shock Prediction for Patients with Miss...     Consensus
# 2   Class-Modeling of Septic Shock With Hyperdimen...     Consensus
# 3   Learning to Treat Hypotensive Episodes in Seps...     Consensus
# 4   A self-supervised method for treatment recomme...     Consensus
# ..                                                ...           ...
# 70  Sepsis Prediction and Vital Signs Ranking in I...     Consensus
# 71  The Actor Search Tree Critic (ASTC) for Off-Po...     Consensus
# 72  Continuous State-Space Models for Optimal Seps...     Consensus
# 73   Deep Reinforcement Learning for Sepsis Treatment     Consensus
# 74  Trading-Off Cost of Deployment Versus Accuracy...     Consensus
#
#                                               Title.1  Year of publication  \
# 0   Deep Inverse Reinforcement Learning for Sepsis...                 2019
# 1   Septic Shock Prediction for Patients with Miss...                 2014
# 2   Class-Modeling of  Septic Shock With Hyperdime...                 2021
# 3   Learning to Treat Hypotensive Episodes in Seps...                 2021
# 4   A self-supervised method for treatment recomme...                 2021
# ..                                                ...                  ...
# 70  Sepsis Prediction and Vital Signs Ranking in I...                 2018
# 71  The Actor Search Tree Critic (ASTC) for Off-Po...                 2018
# 72  Continuous State-Space Models for Optimal Seps...                 2017
# 73   Deep Reinforcement Learning for Sepsis Treatment                 2017
# 74  Trading-Off Cost of Deployment Versus Accuracy...                 2016
#
#              Funding source  Supervised learning  Unsupervised learning  \
# 0   Unclear or not reported                 True                  False
# 1                  Academic                 True                  False
# 2   Unclear or not reported                 True                  False
# 3                  Academic                 True                  False
# 4                  Academic                 True                  False
# ..                      ...                  ...                    ...
# 70               Commercial                 True                  False
# 71  Unclear or not reported                False                  False
# 72                 Academic                False                  False
# 73                    Mixed                False                  False
# 74  Unclear or not reported                 True                  False
#
#     Reinforcement learning  ...  Definition requires high lactate  \
# 0                     True  ...                             False
# 1                    False  ...                             False
# 2                    False  ...                             False
# 3                     True  ...                             False
# 4                     True  ...                             False
# ..                     ...  ...                               ...
# 70                   False  ...                             False
# 71                    True  ...                             False
# 72                    True  ...                             False
# 73                    True  ...                             False
# 74                   False  ...                             False
#
#    Internal validation  External retrospective validation (other hospitals)  \
# 0                 True                                              False
# 1                 True                                              False
# 2                False                                              False
# 3                 True                                              False
# 4                 True                                              False
# ..                 ...                                                ...
# 70                True                                              False
# 71                True                                              False
# 72                True                                              False
# 73                True                                              False
# 74                True                                              False
#
#     External retrospective validation (separate dataset)  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 70                                              False
# 71                                              False
# 72                                              False
# 73                                              False
# 74                                              False
#
#     Prospective observational validation  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 70                                 False
# 71                                 False
# 72                                 False
# 73                                 False
# 74                                 False
#
#     Non-randomised interventional validation (clinical trial)  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 70                                              False
# 71                                              False
# 72                                              False
# 73                                              False
# 74                                              False
#
#    Randomised interventional validation (clinical trial)  Regulatory approval  \
# 0                                               False                   False
# 1                                               False                   False
# 2                                               False                   False
# 3                                               False                   False
# 4                                               False                   False
# ..                                                ...                     ...
# 70                                              False                   False
# 71                                              False                   False
# 72                                              False                   False
# 73                                              False                   False
# 74                                              False                   False
#
#    Post-deployment surveillance  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ..                          ...
# 70                        False
# 71                        False
# 72                        False
# 73                        False
# 74                        False
#
#                        Comments (enter 'N/A' if none)
# 0   A very short paper that seems to accompany a c...
# 1                                                 NaN
# 2                                   check validation
# 3   The causal inference aspects of this study are...
# 4                          supervised or unsupervised
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74  Interesting consideration of financial cost in...
#
# [75 rows x 42 columns]

# %%
year_bins = list(range(2000, 2023, 1))
papers_df["Year of publication"].plot.hist(bins=year_bins, width=0.8)
plt.xlabel("Year of publication")
plt.ylabel("Numper of papers")
plt.show()
